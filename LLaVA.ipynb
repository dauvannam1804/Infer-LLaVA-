# %% [markdown]
# # **Mount drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/AIVNRG25"
# Out:
# /content/drive/MyDrive/Colab Notebooks/AIVNRG25

# %%
# !git clone https://github.com/haotian-liu/LLaVA.git

# %%
# %cd LLaVA
# Out:
# /content/drive/MyDrive/Colab Notebooks/AIVNRG25/LLaVA

# %% [markdown]
# # **Install**

# %% [markdown]
# ## **Install conda**

# %%
# !conda --version
# !which python
# !python --version
# Out:
# /bin/bash: line 1: conda: command not found
# /usr/local/bin/python
# Python 3.12.11

# %%
# !echo $PYTHONPATH
# %env PYTHONPATH=
# !echo $PYTHONPATH
# Out:
# /env/python
# env: PYTHONPATH=

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
# https://dev.to/hetal_patel/how-to-install-and-run-conda-on-google-colab-1k09
################################################################################

# !wget https://repo.anaconda.com/miniconda/Miniconda3-py310_24.1.2-0-Linux-x86_64.sh
# !chmod +x Miniconda3-py310_24.1.2-0-Linux-x86_64.sh
# !bash ./Miniconda3-py310_24.1.2-0-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2025-08-22 13:16:15--  https://repo.anaconda.com/miniconda/Miniconda3-py310_24.1.2-0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134948792 (129M) [application/octet-stream]
# Saving to: ‘Miniconda3-py310_24.1.2-0-Linux-x86_64.sh.1’
#
# Miniconda3-py310_24 100%[===================>] 128.70M  65.4MB/s    in 2.0s
#
# 2025-08-22 13:16:17 (65.4 MB/s) - ‘Miniconda3-py310_24.1.2-0-Linux-x86_64.sh.1’ saved [134948792/134948792]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# ...
#
#
# ...
#
# done
# done
# installation finished.

# %%
# !which conda
# !conda --version
# Out:
# /usr/local/bin/conda
# conda 24.1.2

# %%
import sys
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.12/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/usr/local/lib/python3.7/site-packages/']

# %%
'''
Any package that you install with Conda will be installed into the directory /usr/local/lib/python3.10/site-packages
So you will need to add this directory to sys.path in order for these packages to be available for import.
'''

import sys
sys.path.append("/usr/local/lib/python3.10/site-packages")

# %%
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.12/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/usr/local/lib/python3.7/site-packages/',
#  '/usr/local/lib/python3.10/site-packages']

# %% [markdown]
# # **Create conda environment**

# %%
# !conda create -n llava python=3.10 -y
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/llava
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     ca-certificates-2025.7.15  |       h06a4308_0         126 KB
#     expat-2.7.1                |       h6a678d5_0         182 KB
#     ld_impl_linux-64-2.40      |       h12ee557_0         710 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libxcb-1.17.0              |       h9b100fa_0         430 KB
#     ncurses-6.5                |       h7934f7d_0         1.1 MB
#     openssl-3.0.17             |       h5eee18b_0         5.2 MB
#     pip-25.1                   |     pyhc872135_2         1.3 MB
# ...

# %%
# !source activate /usr/local/envs/llava

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                     /usr/local
# llava                    /usr/local/envs/llava

# %%
# !conda run -n llava python --version
# Out:
# Python 3.10.18

# %% [markdown]
# ## **Install package**

# %%
# !conda run -n llava pip install -qe .
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 93.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 94.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 22.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 77.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 56.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 111.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 113.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 38.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 57.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Quick start**

# %%
from llava.model.builder import load_pretrained_model
from llava.mm_utils import get_model_name_from_path
from llava.eval.run_llava import eval_model

model_path = "liuhaotian/llava-v1.5-7b-lora"

tokenizer, model, image_processor, context_len = load_pretrained_model(
    model_path=model_path,
    model_base=None,
    model_name=get_model_name_from_path(model_path)
)
# Out:
# You are using a model of type llava to instantiate a model of type llava_llama. This is not supported for all configurations of models and can yield errors.
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# Loading LLaVA from base model...
# pytorch_model.bin.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-996545334.py in <cell line: 0>()
#       5 model_path = "liuhaotian/llava-v1.5-7b-lora"
#       6
# ...

# %%
model_path = "liuhaotian/llava-v1.5-7b-lora"
prompt = "What are the things I should be cautious about when I visit here?"
image_file = "https://llava-vl.github.io/static/images/view.jpg"

args = type('Args', (), {
    "model_path": model_path,
    "model_base": None,
    "model_name": get_model_name_from_path(model_path),
    "query": prompt,
    "conv_mode": None,
    "image_file": image_file,
    "sep": ",",
    "temperature": 0,
    "top_p": None,
    "num_beams": 1,
    "max_new_tokens": 512
})()

eval_model(args)
# Out:
# You are using a model of type llava to instantiate a model of type llava_llama. This is not supported for all configurations of models and can yield errors.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2964963226.py in <cell line: 0>()
#      17 })()
#      18
# ---> 19 eval_model(args)
#
# /content/drive/MyDrive/Colab Notebooks/AIVNRG25/LLaVA/llava/eval/run_llava.py in eval_model(args)
#      53
#      54     model_name = get_model_name_from_path(args.model_path)
# ---> 55     tokenizer, model, image_processor, context_len = load_pretrained_model(
#      56         args.model_path, args.model_base, model_name
#      57     )
#
# /content/drive/MyDrive/Colab Notebooks/AIVNRG25/LLaVA/llava/model/builder.py in load_pretrained_model(model_path, model_base, model_name, load_8bit, load_4bit, device_map, device, use_flash_attn, **kwargs)
# ...
